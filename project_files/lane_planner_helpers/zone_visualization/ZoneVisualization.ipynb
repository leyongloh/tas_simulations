# %%
# Import necessary libraries
import cv2
import numpy as np
  
# Read an image
img = cv2.imread("image.png")
line_width = 0.75  
car_len = 0.56
laser_len = 3
angle = np.pi/9

# Define an array of endpoints of triangle
tan = np.tan(angle)
shift =  tan * 150

#top row
#cv2.rectangle(img, (100, 25), (200, 175), (255, 0, 0), -1)
#cv2.rectangle(img, (200, 25), (300, 175), (255, 0, 0), -1)
#cv2.rectangle(img, (300, 25), (400, 175), (255, 0, 0), -1)

#second row
cv2.rectangle(img, (130, 215), (230, 285), (255, 0, 0), 5)
cv2.rectangle(img, (270, 215), (370, 285), (255, 0, 0), 5)

#third row
cv2.rectangle(img, (130, 285), (210, 425), (255, 0, 0), 5)
cv2.rectangle(img, (210, 285), (290, 425), (255, 0, 0), 5)
cv2.rectangle(img, (290, 285), (370, 425), (255, 0, 0), 5)

#car
cv2.rectangle(img, (230, 215), (270, 285), (0, 0, 0), -1)


#points = np.array([[160, 130], [350, 130], [250, 300]])
  
# Use fillPoly() function and give input as
# image, end points,color of polygon
# Here color of polygon will blue
#cv2.fillPoly(img, pts=[points], color=(255, 0, 0))
  
# Displaying the image
#cv2.imshow("Triangle", img)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
pts_left = np.array([[(130 + shift),75], [(210 + shift),75], [210,215], [130,215]], np.int32)
pts_left = pts_left.reshape((-1,1,2))
cv2.polylines(img,[pts_left],True,(255, 0, 0),5)

pts_mid = np.array([[(210 + shift),75], [(290 + shift),75], [290,215], [210,215]], np.int32)
pts_mid = pts_mid.reshape((-1,1,2))
cv2.polylines(img,[pts_mid],True,(255, 0, 0),5)

pts_right = np.array([[(290 + shift),75], [(370 + shift),75], [370,215], [290,215]], np.int32)
pts_right = pts_right.reshape((-1,1,2))
cv2.polylines(img,[pts_right],True,(255, 0, 0),5)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
cv2.imshow('image', img)
  
# wait for the user to press any key to 
# exit window
cv2.waitKey(0)
  
# Closing all open windows
cv2.destroyAllWindows()
img
